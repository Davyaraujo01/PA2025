# %% [markdown]
# #STF

# %%
nome = str(input('digite um nome:'))

if(nome == 'Eduarda'):
  print('Usuario cadastrado')
else:
  print('Usuario nao cadastrado!')
# Out:
# digite um nome:Ana
# Usuario cadastrado

# %% [markdown]
# #ANO BISSEXTO

# %%
print("-"*79, "IDENTIFIQUE SE O ANO É BISSEXTO" ,"-"*79)
ano = int(input('digite um ano:'))
if ano % 4 == 0:
  print("É um ano bissexto!")
else:
  print("Não é um ano bissexto!")
# Out:
# ------------------------------------------------------------------------------- IDENTIFIQUE SE O ANO É BISSEXTO -------------------------------------------------------------------------------
# digite um ano:2025
# Não é um ano bissexto!
